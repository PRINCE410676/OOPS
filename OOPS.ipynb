# %% [markdown]
# OOPS

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#     - This is the well defined language by Python and uses many things in tools.
# 2. What is a class in OOP?
#     - Class have be used in oops program because class in practice time.
# 3. What is an object in OOP?
#     - They have many objects in use of oops such as class, double underscore, decorates, __inte__ and so on.
# 4. What is the difference between abstraction and encapsulation?
#     - They have many difference in this between.
# 5. What are dunder methods in Python?
#     - This is underscore in use by dunder method in python.
# 6. Explain the concept of inheritance in OOP?
#     - They have many times.
# 7. What is polymorphism in OOP?
#     - This is many type of polymorphism.
# 8. How is encapsulation achieved in Python?
#     - Yes.
# 9. What is a constructor in Python?
#     - Such as real life example.
# 10. What are class and static methods in Python?
#     - Yes.

# %%
# Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
'''
class Animal:
    def speak(self):
        print("Generic message")

class Dog(Animal):
    def speak(self):
        print("Bark!")
        '''
# Out:
# '\nclass Animal:\n    def speak(self):\n        print("Generic message")\n\nclass Dog(Animal):\n    def speak(self):\n        print("Bark!")\n        '

# %%
# Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# %%
#  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
'''
class Vehicle:
    def __init__(self, type):
        self.type = type
'''
# Out:
# '\nclass Vehicle:\n    def __init__(self, type):\n        self.type = type\n'

# %%
#  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
'''
class Bird:
    def fly(self):
        print("Generic message")

class Sparrow(Bird):
    def fly(self):
        print("I can fly")

class Penguin(Bird):
    def fly(self):
        print("I can't fly")
'''
# Out:
# '\nclass Bird:\n    def fly(self):\n        print("Generic message")\n\nclass Sparrow(Bird):\n    def fly(self):\n        print("I can fly")\n\nclass Penguin(Bird):\n    def fly(self):\n        print("I can\'t fly")\n'

# %%
#  Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
'''
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        self.__balance -= amount

    def check_balance(self):
        return self.__balance
'''
# Out:
# '\nclass BankAccount:\n    def __init__(self, balance):\n        self.__balance = balance\n        \n    def deposit(self, amount):\n        self.__balance += amount\n        \n    def withdraw(self, amount):\n        self.__balance -= amount\n        \n    def check_balance(self):\n        return self.__balance\n'

# %%
# Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play()
'''
class Instrument:
    def play(self):
        print("Generic message")

class Guitar(Instrument):
    def play(self):
        print("I can play guitar")

class Piano(Instrument):
    def play(self):
        print("I can play piano")
'''
# Out:
# '\nclass Instrument:\n    def play(self):\n        print("Generic message")\n\nclass Guitar(Instrument):\n    def play(self):\n        print("I can play guitar")\n\nclass Piano(Instrument):\n    def play(self):\n        print("I can play piano")\n'

# %%
# Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
'''
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b
'''
# Out:
# '\nclass MathOperations:\n    @classmethod\n    def add_numbers(cls, a, b):\n        return a + b\n    \n    @staticmethod\n    def subtract_numbers(a, b):\n        return a - b\n'

# %%
#  Implement a class Person with a class method to count the total number of persons created.
'''
class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count
'''
# Out:
# '\nclass Person:\n    count = 0\n    \n    def __init__(self):\n        Person.count += 1\n        \n    @classmethod\n    def get_count(cls):\n        return cls.count\n'

# %%
# Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
'''
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"
'''
# Out:
# '\nclass Fraction:\n    def __init__(self, numerator, denominator):\n        self.numerator = numerator\n        self.denominator = denominator\n        \n    def __str__(self):\n        return f"{self.numerator}/{self.denominator}"\n'

# %%
# Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
'''
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
'''
# Out:
# '\nclass Vector:\n    def __init__(self, x, y):\n        self.x = x\n        self.y = y\n        \n    def __add__(self, other):\n        return Vector(self.x + other.x, self.y + other.y)\n'

# %%
# Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
'''
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
'''
# Out:
# '\nclass Person:\n    def __init__(self, name, age):\n        self.name = name\n        self.age = age\n'

# %%
# Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
'''
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)
'''
# Out:
# '\nclass Student:\n    def __init__(self, name, grades):\n        self.name = name\n        self.grades = grades\n        \n    def average_grade(self):\n        return sum(self.grades) / len(self.grades)\n'

# %%
# Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
'''
class Rectangle:
    def __init__(self):
'''
# Out:
# '\nclass Rectangle:\n    def __init__(self):\n'

# %%
# Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.Java + DSA Pwskills
'''
class Employee:
    def calculate_salary(self, hours_worked, hourly_rate):
        return hours_worked * hourly
class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate):
        return super().calculate_salary(hours_worked, hourly_rate) + 1000
class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate):
        return super().calculate_salary(hours_worked, hourly_rate) + 1000
'''
# Out:
# '\nclass Employee:\n    def calculate_salary(self, hours_worked, hourly_rate):\n        return hours_worked * hourly\nclass Manager(Employee):\n    def calculate_salary(self, hours_worked, hourly_rate):\n        return super().calculate_salary(hours_worked, hourly_rate) + 1000\nclass Manager(Employee):\n    def calculate_salary(self, hours_worked, hourly_rate):\n        return super().calculate_salary(hours_worked, hourly_rate) + 1000\n'

# %%
# Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
'''
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity
'''
# Out:
# '\nclass Product:\n    def __init__(self, name, price, quantity):\n        self.name = name\n        self.price = price\n        self.quantity = quantity\n        \n    def total_price(self):\n        return self.price * self.quantity\n'

# %%
# Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
'''
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")
'''
# Out:
# '\nfrom abc import ABC, abstractmethod\n\nclass Animal(ABC):\n    @abstractmethod\n    def sound(self):\n        pass\n\nclass Cow(Animal):\n    def sound(self):\n        print("Moo")\n\nclass Sheep(Animal):\n    def sound(self):\n        print("Baa")\n'

# %%
# Create a class Book with attributes title, author, and year_published. Add a method get_book_info() thatreturns a formatted string with the book's details.
'''
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"{self.title} by {self.author} ({self.year_published})"
'''
# Out:
# '\nclass Book:\n    def __init__(self, title, author, year_published):\n        self.title = title\n        self.author = author\n        self.year_published = year_published\n\n    def get_book_info(self):\n        return f"{self.title} by {self.author} ({self.year_published})"\n'

# %%
# Create a class House with attributes address and price. Create a derived class Mansion that adds anattribute number_of_rooms.
'''
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of
        super().__init__(address, price)
        self.number_of_rooms = number_of
'''
# Out:
# '\nclass House:\n    def __init__(self, address, price):\n        self.address = address\n        self.price = price\n\nclass Mansion(House):\n    def __init__(self, address, price, number_of\n        super().__init__(address, price)\n        self.number_of_rooms = number_of\n'
